# %%
import requests

url = "https://api-hoaxy.p.rapidapi.com/tweets"

querystring = {"ids":"%5B29317%2C 68363%5D"}

headers = {
    'x-rapidapi-host': "api-hoaxy.p.rapidapi.com",
    'x-rapidapi-key': "8bd7508073mshe5c51e555173ee1p1a803ajsnebd7566cb65b"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"error":"Empty of `ids`\nFormat error of `ids`","status":"ERROR"}

# %%
import http.client

conn = http.client.HTTPSConnection("api-hoaxy.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-hoaxy.p.rapidapi.com",
    'x-rapidapi-key': "8bd7508073mshe5c51e555173ee1p1a803ajsnebd7566cb65b"
    }

conn.request("GET", "/tweets?ids=%255B29317%252C%2068363%255D", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"error":"Empty of `ids`\nFormat error of `ids`","status":"ERROR"}

# %%
import http.client
import json

conn = http.client.HTTPSConnection("api-hoaxy.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-hoaxy.p.rapidapi.com",
    'x-rapidapi-key': "8bd7508073mshe5c51e555173ee1p1a803ajsnebd7566cb65b"
    }

def categorizeScore(score, median):
    if(score < median - (median) * .05):
        return "Likely True"
    if (score > median - (median * .1) and score < median + (median * .05)):
        return "Possibly True"
    if (score > median + (median) and score < median + (median * .05)):
        return "Possibly False"
    if (score > median + (median * .05) and score < median + (median * .1)):
        return "Likely False"
    else:
        return "Very Likely False"

def getMean(JSON):
    counter = 0
    totalScore = 0
    for item in JSON["articles"]:
        if(item["site_type"] == "claim"):
            counter = counter  +1
            totalScore = totalScore + int(item["score"])
    return totalScore / counter

def printScores(JSON):
    mean = getMean(JSON)
    print(mean)
    for item in JSON["articles"]:
        print(item["title"])
        print(categorizeScore(item["score"], mean))
        #print(item["score"])

def getHeadlineScore(title):

    title = title.replace(" ", "+")
    title = title.replace("_", "+")
    title = title.replace("-", "+")

    conn.request("GET", "/articles?sort_by=relevant&use_lucene_syntax=false&query=" + title, headers=headers)

    res = conn.getresponse()
    data = res.read()
    JSON = json.loads(data.decode("utf-8"))
    getMean(JSON)
    printScores(JSON)
getHeadlineScore("Obama")
# Out:
# 82.86021505376344
# Comey Damns Trump By Saying He Didn’t Write Memos On Obama Because Obama Was Truthful
# Possibly True
# Obama TV: Is Obama Planning A “Fake News” Outlet Of His Own?
# Possibly True
# Obama To Clinton
# Possibly True
# Trump VS Obama
# Possibly True
# Michelle Obama Accidentally Pops Out and Obama Laughs | Blogging/Citizen Journalism
# Possibly True
# America's Economy Before Obama Versus After Obama
# Possibly True
# Obama Classmate
# Possibly True
# Barack Obama Archives - FactCheck.org
# Possibly True
# Obama: Michelle Obama To Run For President In 2020
# Possibly True
# Obama Articles
# Possibly True
# Obama Promises to Leave United States | Obama
# Possibly True
# Michelle Obama wears the pants, according ex-Obama aide » Intellihu
# Possibly True
# Who IS Obama? | Obama
# Possibly True
# Obama Could Be Facing 10 Years to Life in Prison (Video) Trap Is Closing In On Fraud Obama Who Acted As President | Obama Birthplace Controversy
# Possibly True
# obama | Snopes.com
# Likely False
# Obama Fan Club Claims Obama Was Tougher On Immigration Than Trump
# Possibly True
# Obama "It Was You!!" | Obama
# Possibly True
# Obama the Manchurian | Obama
# Possibly True
# Barack Obama – Yes Michelle Obama Is a Man / Transgender | New World Order
# Possibly True
# Obama Morphing into a Beast Dreams and Confirmations (Video) | Obama
# Possibly True
# Russian Official: "Obama Is A KGB Agent" | Obama
# Possibly True
# Michelle (Michael) Obama is a Baphomet - Confirmed! | Obama
# Possibly True
# Obama Changed His Name in Canada? -Video | Obama
# Possibly True
# Massive Reversal Of Trump On Truce With Obama: Blasts Fraud Obama About Lies And His Sketchy Past History (Video) | Obama
# Likely False
# Obama Supporters Will Be Ecstatic Over This Comprehensive List Of 423 Obama Lies (Video) | Obama
# Likely False
# Obama Bilderberg Video: Plane Takes Off With Reporters But NOT Obama | Obama
# Likely False
# OBAMA --- Sexual Harassment COMPLAINT | Obama
# Possibly True
# Obama Throws Israel to the Wolves | Obama
# Possibly True
# Pastor Says Obama May Be Antichrist; Obama Leads To Antichrist. Pastor Demonized Obama In Past: "Stop" (Video) | Obama
# Possibly True
# Barack Obama
# Possibly True
# Obama: 7 Years of Famine | Obama
# Possibly True
# That Obama Leotard Drag Photo? It's Fake | Obama
# Possibly True
# Obama Appointed Judge Rules On Obama Social Security Number FOIA Case | Obama Birthplace Controversy
# Possibly True
# Legacy Of Ashes: Obama. (Video) Obama Will Go Down As One Of The Worst Presidents Of All Time. Traitor And Damned | Obama
# Possibly True
# Can Obama Leave With Class, Grace? | Obama
# Possibly True
# Obama Eats Nuclear Power for Lunch | Obama
# Possibly True
# Obama Is The Biblical Antichrist? Video 2 On Obama Antichrist. Yes I Really Believe Obama Is The Antichrist (Video) | Obama Birthplace Controversy
# Possibly True
# Obama: His Legacy of Damage Done to America | Obama
# Possibly True
# Obama Thanks Obama for Growing Economy
# Very Likely False
# Spicer Denies “Obama Wiretapping” Refers To Obama: “Donald Trump Said ‘Obama’ In Quotes Very Clearly”
# Possibly True
# Countdown To Dynamite Revelations On Obama Tomorrow In Book = 'Rising Star: The Making of Barack Obama' (Video) | Obama
# Possibly True
# Trump: Obama Born In Somalia Not Kenya | Obama
# Possibly True
# Disgraceful Obama Pic: Holding Hands With Gay Lover | Obama
# Possibly True
# Obama – The Racist Agitator | Obama Birthplace Controversy
# Possibly True
# Michelle Obama Archives - FactCheck.org
# Possibly True
# Obama and the Perpetual Presidency
# Possibly True
# Obama, the Anti-President | Obama
# Possibly True
# [WATCH] Michelle Obama Goes On A Despicable Rant Against Men At Obama Fundation Summit
# Possibly True
# Michelle Obama
# Possibly True
# Obama Attacks Trump | Obama
# Possibly True
# Obama dies
# Possibly True
# Obama thanks Obama for robust economic growth | Politics
# Possibly True

# %%
import requests

url = "https://api-hoaxy.p.rapidapi.com/latest-articles"

querystring = {"domains":'[infowars.com]',"past_hours":"100"}

headers = {
    'x-rapidapi-host': "api-hoaxy.p.rapidapi.com",
    'x-rapidapi-key': "8bd7508073mshe5c51e555173ee1p1a803ajsnebd7566cb65b"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"error":"Not valid values nor JSON string of `domains`","status":"Parameter error"}

# %%
# !pip install torch===1.4.0 torchvision===0.5.0 -f https://download.pytorch.org/whl/torch_stable.html
    
import torch
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch===1.4.0
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.4.0-cp36-cp36m-win_amd64.whl (796.8MB)
# Collecting torchvision===0.5.0
#   Downloading https://files.pythonhosted.org/packages/80/59/ba66ebe892ec8302048434455fb6a9944eb0a78315184f8757094ba95435/torchvision-0.5.0-cp36-cp36m-win_amd64.whl (1.2MB)
# Requirement already satisfied: six in c:\users\wisne\anaconda3\lib\site-packages (from torchvision===0.5.0) (1.10.0)
# Requirement already satisfied: numpy in c:\users\wisne\anaconda3\lib\site-packages (from torchvision===0.5.0) (1.17.4)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\wisne\anaconda3\lib\site-packages (from torchvision===0.5.0) (4.1.1)
# Requirement already satisfied: olefile in c:\users\wisne\anaconda3\lib\site-packages (from pillow>=4.1.1->torchvision===0.5.0) (0.44)
# Installing collected packages: torch, torchvision
# Successfully installed torch-1.4.0 torchvision-0.5.0
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import torch, torchtext
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-98-3654316b1448> in <module>()
# ----> 1 import torch, torchtext
#
# ModuleNotFoundError: No module named 'torchtext'
